# %%
import pandas as pd
#read data frame
df=pd.read_csv('C:\\Users\\akash\\Desktop\\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.loc[[10,20,135] ,["SepalLengthCm"]]
# Out:
#      SepalLengthCm
# 10             5.4
# 20             5.4
# 135            7.7

# %%
df.iloc[[10,100,10] , [1,2,3,4]]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 10             5.4           3.7            1.5           0.2
# 100            6.3           3.3            6.0           2.5
# 10             5.4           3.7            1.5           0.2

# %%
df.loc[[10,130,50] , ["PetalLengthCm"]]
# Out:
#      PetalLengthCm
# 10             1.5
# 130            6.1
# 50             4.7

# %%
df.iloc[10:120:2 , 2:4]
# Out:
#      SepalWidthCm  PetalLengthCm
# 10            3.7            1.5
# 12            3.0            1.4
# 14            4.0            1.2
# 16            3.9            1.3
# 18            3.8            1.7
# 20            3.4            1.7
# 22            3.6            1.0
# 24            3.4            1.9
# 26            3.4            1.6
# 28            3.4            1.4
# 30            3.1            1.6
# 32            4.1            1.5
# 34            3.1            1.5
# 36            3.5            1.3
# 38            3.0            1.3
# 40            3.5            1.3
# 42            3.2            1.3
# 44            3.8            1.9
# 46            3.8            1.6
# 48            3.7            1.5
# 50            3.2            4.7
# 52            3.1            4.9
# 54            2.8            4.6
# 56            3.3            4.7
# 58            2.9            4.6
# 60            2.0            3.5
# 62            2.2            4.0
# ...

# %%
df.drop([1,2])
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# ..              ...
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
df.drop(["SepalLengthCm",'PetalLengthCm'],axis = 1)
# Out:
#       Id  SepalWidthCm  PetalWidthCm         Species
# 0      1           3.5           0.2     Iris-setosa
# 1      2           3.0           0.2     Iris-setosa
# 2      3           3.2           0.2     Iris-setosa
# 3      4           3.1           0.2     Iris-setosa
# 4      5           3.6           0.2     Iris-setosa
# ..   ...           ...           ...             ...
# 145  146           3.0           2.3  Iris-virginica
# 146  147           2.5           1.9  Iris-virginica
# 147  148           3.0           2.0  Iris-virginica
# 148  149           3.4           2.3  Iris-virginica
# 149  150           3.0           1.8  Iris-virginica
#
# [150 rows x 4 columns]

# %%
df1=df

# %%
df1.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.size
# Out:
# 900

# %%
df.shape
# Out:
# (150, 6)

# %%
df1[akash]=100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df1[akash]=100
#
# NameError: name 'akash' is not defined

# %%
df1["akki"]=100
df1
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  akki
# 0       Iris-setosa   100
# 1       Iris-setosa   100
# 2       Iris-setosa   100
# 3       Iris-setosa   100
# ...

# %%
import numpy as np

# %%
df.iloc[1,6]=np.nan
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 1       Iris-setosa    NaN
# 2       Iris-setosa  100.0
# 3       Iris-setosa  100.0
# ...

# %%
df.loc[3,'SepalLengthCm']=np.nan
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 1       Iris-setosa    NaN
# 2       Iris-setosa  100.0
# 3       Iris-setosa  100.0
# ...

# %%
df2=df1
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 1       Iris-setosa    NaN
# 2       Iris-setosa  100.0
# 3       Iris-setosa  100.0
# ...

# %%
df2.dropna()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 2       Iris-setosa  100.0
# 4       Iris-setosa  100.0
# 5       Iris-setosa  100.0
# ...

# %%
df3=df2
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 1       Iris-setosa    NaN
# 2       Iris-setosa  100.0
# 3       Iris-setosa  100.0
# ...

# %%
df2.dropna(axis=0, how='any')
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 4      5            5.0           3.6            1.4           0.2
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 2       Iris-setosa  100.0
# 4       Iris-setosa  100.0
# 5       Iris-setosa  100.0
# ...

# %%
import numpy as np
df2[100]=np.nan
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki  100
# 0       Iris-setosa  100.0  NaN
# 1       Iris-setosa    NaN  NaN
# 2       Iris-setosa  100.0  NaN
# ...

# %%
df2=df2.dropna(axis=1,how='all')
df2
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species   akki
# 0       Iris-setosa  100.0
# 1       Iris-setosa    NaN
# 2       Iris-setosa  100.0
# 3       Iris-setosa  100.0
# ...

# %%
df2.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    1
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# akki             1
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  149 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
#  6   akki           149 non-null    float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 8.3+ KB

# %%
df2.corr()
# Out:
# C:\Windows\Temp\ipykernel_22024\1778878097.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.711917     -0.397729       0.882747
# SepalLengthCm  0.711917       1.000000     -0.109131       0.870215
# SepalWidthCm  -0.397729      -0.109131      1.000000      -0.420516
# PetalLengthCm  0.882747       0.870215     -0.420516       1.000000
# PetalWidthCm   0.899759       0.815610     -0.356544       0.962757
# akki                NaN            NaN           NaN            NaN
#
#                PetalWidthCm  akki
# Id                 0.899759   NaN
# SepalLengthCm      0.815610   NaN
# SepalWidthCm      -0.356544   NaN
# PetalLengthCm      0.962757   NaN
# PetalWidthCm       1.000000   NaN
# ...

# %%
df2.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            NaN           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#     akki
# 0  100.0
# 1    NaN
# 2  100.0
# 3  100.0
# 4  100.0

# %%
df2.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species', 'akki'],
#       dtype='object')

# %%
df2.rename( columns={(100): "PetalWidthCm"} ,inplace=True)
df2.head
# Out:
# C:\Windows\Temp\ipykernel_22024\1658136108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.rename( columns={(100): "PetalWidthCm"} ,inplace=True)
# <bound method NDFrame.head of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            NaN           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# ...

# %%
df2.shape
# Out:
# (150, 7)

# %%
df2.columns=list('1234567')
df2
# Out:
#        1    2    3    4    5               6      7
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa  100.0
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa    NaN
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa  100.0
# 3      4  NaN  3.1  1.5  0.2     Iris-setosa  100.0
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa  100.0
# ..   ...  ...  ...  ...  ...             ...    ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica  100.0
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica  100.0
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica  100.0
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica  100.0
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica  100.0
#
# [150 rows x 7 columns]

# %%
df2.fillna(0)
# Out:
#        1    2    3    4    5               6      7
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa  100.0
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa    0.0
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa  100.0
# 3      4  0.0  3.1  1.5  0.2     Iris-setosa  100.0
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa  100.0
# ..   ...  ...  ...  ...  ...             ...    ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica  100.0
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica  100.0
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica  100.0
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica  100.0
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica  100.0
#
# [150 rows x 7 columns]

# %%
df2.fillna(method='ffill')
# Out:
#        1    2    3    4    5               6      7
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa  100.0
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa  100.0
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa  100.0
# 3      4  4.7  3.1  1.5  0.2     Iris-setosa  100.0
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa  100.0
# ..   ...  ...  ...  ...  ...             ...    ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica  100.0
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica  100.0
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica  100.0
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica  100.0
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica  100.0
#
# [150 rows x 7 columns]

# %%
df2
# Out:
#        1    2    3    4    5               6      7
# 0      1  5.1  3.5  1.4  0.2     Iris-setosa  100.0
# 1      2  4.9  3.0  1.4  0.2     Iris-setosa    NaN
# 2      3  4.7  3.2  1.3  0.2     Iris-setosa  100.0
# 3      4  NaN  3.1  1.5  0.2     Iris-setosa  100.0
# 4      5  5.0  3.6  1.4  0.2     Iris-setosa  100.0
# ..   ...  ...  ...  ...  ...             ...    ...
# 145  146  6.7  3.0  5.2  2.3  Iris-virginica  100.0
# 146  147  6.3  2.5  5.0  1.9  Iris-virginica  100.0
# 147  148  6.5  3.0  5.2  2.0  Iris-virginica  100.0
# 148  149  6.2  3.4  5.4  2.3  Iris-virginica  100.0
# 149  150  5.9  3.0  5.1  1.8  Iris-virginica  100.0
#
# [150 rows x 7 columns]

# %%
fill={"7" :df2,'8':100}
fill
# Out:
# {'7':        1    2    3    4    5               6      7
#  0      1  5.1  3.5  1.4  0.2     Iris-setosa  100.0
#  1      2  4.9  3.0  1.4  0.2     Iris-setosa    NaN
#  2      3  4.7  3.2  1.3  0.2     Iris-setosa  100.0
#  3      4  NaN  3.1  1.5  0.2     Iris-setosa  100.0
#  4      5  5.0  3.6  1.4  0.2     Iris-setosa  100.0
#  ..   ...  ...  ...  ...  ...             ...    ...
#  145  146  6.7  3.0  5.2  2.3  Iris-virginica  100.0
#  146  147  6.3  2.5  5.0  1.9  Iris-virginica  100.0
#  147  148  6.5  3.0  5.2  2.0  Iris-virginica  100.0
#  148  149  6.2  3.4  5.4  2.3  Iris-virginica  100.0
#  149  150  5.9  3.0  5.1  1.8  Iris-virginica  100.0
#
#  [150 rows x 7 columns],
#  '8': 100}

# %%
df3=df2.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df3=df2.fillna()
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\lib\site-packages\pandas\core\frame.py:5635, in DataFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    5624 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "value"])
#    5625 @doc(NDFrame.fillna, **_shared_doc_kwargs)
#    5626 def fillna(  # type: ignore[override]
# ...
