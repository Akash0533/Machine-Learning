# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read data frame
df=pd.read_csv('C:\\Users\\akash\\Desktop\\Iris.csv')
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
s=df['Species'].value_counts()
s
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.bar(s.index,s.values)
plt.grid()
plt.show()

# %%
a=df['PetalLengthCm'].value_counts()
a
# Out:
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: PetalLengthCm, dtype: int64

# %%
plt.bar(a.index,a.values)
plt.grid()
plt.show()

# %% [markdown]
# # Bar Plot

# %%
df['PetalLengthCm'].mean()
# Out:
# 3.758666666666666

# %%
df.query('Species == "Iris-setosa"')
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
df1=df.drop(['Id'],axis=1)
print(df1.head(2))
m=df1.mean()
print(m)
print(m.index)
print(m.values)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# SepalLengthCm    5.843333
# SepalWidthCm     3.054000
# PetalLengthCm    3.758667
# PetalWidthCm     1.198667
# dtype: float64
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'], dtype='object')
# [5.84333333 3.054      3.75866667 1.19866667]
# C:\Windows\Temp\ipykernel_19220\981282762.py:3: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   m=df1.mean()

# %%
plt.bar(m.index,m.values,color='red')
plt.grid()
plt.xlabel('Sepal Patel length&Width')
plt.ylabel('Mean')
plt.title('Mean of Sepal/Petal Lenth and Width')
plt.show()

# %%
plt.plot(m.index,m.values,color='red')
plt.grid()
plt.xlabel('Sepal Patel length&Width')
plt.ylabel('Mean')
plt.title('Mean of Sepal/Petal Lenth and Width')
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.barplot(x=m.index,y=m.values)
plt.grid()
plt.title('Bar plot (mean)')
plt.xlabel('Petal,Sapel Length&Width')
plt.ylabel('mean')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.lineplot(x=m.index,y=m.values)
plt.grid()
plt.title('Bar plot (mean)')
plt.xlabel('Petal,Sapel Length&Width')
plt.ylabel('mean')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Scatter Plot

# %%
plt.scatter(x=df[['PetalLengthCm']],y=df[['PetalWidthCm']])
plt.grid()
plt.title('Iris Flowers leaves Lenth & Width')
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.show()

# %%
sns.scatterplot(data=df,x=('PetalLengthCm'),y=('PetalWidthCm'),hue='Species')
plt.grid()
plt.title('Iris Flowers leaves Lenth & Width')
plt.xlabel('PetalLengthCm')
plt.ylabel('PetalWidthCm')
plt.show()

# %% [markdown]
# # Pie Chart

# %%
plt.figure(figsize=(8,8))
plt.pie(m,labels=m.index,autopct="%.2f%%")
plt.legend(loc=4)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(m,labels=m.index,explode=[0,0,.1,0] ,shadow=True)
plt.legend(loc=4)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(m,labels=m.index,explode=[0,0,.9,0] ,shadow=True)
plt.legend(loc=4)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(m,labels=m.index,explode=[.2,0.3,.1,0.4] ,shadow=True)
plt.legend(loc=4)
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.hist(df['PetalLengthCm'],color='lightblue')
plt.show()

# %%
sns.histplot(df['SepalLengthCm'])
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(8,8))
b=df.drop(['Id' ,'Species'],axis=1)
plt.boxplot(b)
plt.show()

# %% [markdown]
# #sns.catplot(kind = "box" ,data =b)
# sns.boxplot(data=b)
# plt.show()

# %% [markdown]
# # Subplot

# %%
plt.subplot(1,2,2)
plt.hist(df['PetalLengthCm'].values,color='lightgreen')
plt.subplot(1,2,1)
sns.distplot(df['SepalLengthCm'],hist=True)
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_19220\3308743879.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'],hist=True)

# %% [markdown]
# - 1. please make histo

# %%
plt.subplot(1,2,2)
plt.hist(df['PetalLengthCm'].values,color='lightgreen')
plt.subplot(1,2,1)
sns.distplot(df['SepalLengthCm'],hist=True)
plt.show()
plt.subplot(1,2,2)
plt.hist(df['PetalLengthCm'].values,color='lightgreen')
plt.subplot(1,2,1)
sns.distplot(df['SepalLengthCm'],hist=True)
plt.show()
# Out:
# C:\Windows\Temp\ipykernel_19220\1855572060.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'],hist=True)
# C:\Windows\Temp\ipykernel_19220\1855572060.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['SepalLengthCm'],hist=True)

# %%
corr=df.corr()
corr
# Out:
# C:\Windows\Temp\ipykernel_19220\3182140910.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
sns.heatmap(corr,annot=True)
plt.xticks(rotation=383)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.pairplot(df,hue='Species')

# %%
sns.pairplot(df)

# %%
plt.subplot(2,1,1)

plt.xlabel('Sepal Patel length&width ')
plt.ylabel('Mean')
plt.title(' Mean of Sepal/Patel Length and width')
plt.grid()
plt.plot(m.index,m.values,color='red')
plt.subplot(2,1,2)
plt.bar(m.index,m.values,color='yellow')
#plt.scatter(m.index,m.values,color='blue',marker='*')
plt.grid()
plt.show()

# %%
#sns.catplot(kind = "box",data =b)
sns.boxplot(data=b)
plt.show()

# %%
df.head(2)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa

# %%
y=[50,160,50,80,350,280]
x=['Potato/kg','Mango/kg','Bananas/wicked','Tomato/kg','Kiwi/piece','Apple/kg']

# %%
plt.figure(figsize=(10,3))
plt.plot(x,y,color='red')
plt.bar(x,y,color='yellow')
plt.scatter(x,y,color='blue',marker='*')
plt.grid()
plt.xlabel('Grocery ')
plt.ylabel('Price in Rs.')
plt.title("Grocery's prices")
plt.show()

# %%
import seaborn as sns
plt.figure(figsize=(6,5))
sns.lineplot(x=m.index,y=m.values)
plt.grid()
plt.title('Bar plot (mean)')
plt.xlabel('Petal,Sapel Length&width')
plt.ylabel('mean')
plt.show()

# %% [markdown]
# # Akash Kumar
# Truba College Of Science & Technology
# Enrollment No. 0533CL211001
